# %% [markdown]
# # A Simple TensorFlow Tutorial

# %% [markdown]
# ## 1. Introduction - What is TensorFlow
#
# TensorFlow is a framework developed by Google which is designed mainly for machine learning tasks, especially neural networks. It highly abstracts the usage of models so that users only need to adjust several very necessary parameters and TensorFlow will care about all the mechanism and realization details underneath for you. It also opens low level structures and shaped model parts for users to use and flexibly assemble their own customized models. TensorFlow supports GPU mode as well and has libraries for many programming languages including Python, C++, Java and Go.

# %% [markdown]
# ## 2. Installation and Verification
#
# In this section, I will introduce how to install TensorFlow's Python library on your computer and how to test if your installation works.

# %% [markdown]
# ### 2.1 Installation
#
# This link gives a very detailed installation guide for different operating systems (Ubuntu, MacOS, Window): https://www.tensorflow.org/install/. Here is the simplest one using pip from command line without GPU support:
#
# $ pip install tensorflow
#
# It is recommended to use the non-GPU version of TensorFlow first for exploring the basics easier. If you want to install the GPU one, please refer to the above link as well for detailed installation steps and notices.

# %% [markdown]
# ### 2.2 Validate your installation
#
# Use the short program below to validate if tensorflow is ready to run on your machine. It should print out "Hello, TensorFlow" on your console.
#
# (Citation: https://www.tensorflow.org/install/install_linux#ValidateYourInstallation)

# %%
import tensorflow as tf
hello = tf.constant('Hello, TensorFlow!')
sess = tf.Session()
print(sess.run(hello))
# Out:
# /home/shuqih/ENTER/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# b'Hello, TensorFlow!'

# %% [markdown]
# ## 3. TensorFlow Big Picture

# %% [markdown]
# ![title](images/TensorFlowProgrammingEnvironment.png)
#
# (Citation: https://www.tensorflow.org/get_started/get_started_for_beginners)

# %% [markdown]
# This picture shows the hierarchical structure of TensorFlow framework. Basically, it provides the high level OOP APIs called Estimators which are complete machine learning models. You can use them in really simple ways to run a fairly complicated machine learning task, especially neural network tasks. What's more, you can also use the middle level APIs which are major and common model components, for example Layers to build layers of network and Datasets to pre-process raw data into usable forms and feed data to the model, to customize your own implementations.

# %% [markdown]
# ## 4. Main Components of TensorFlow

# %% [markdown]
# ### 4.1 Intuition
#
# Using TensorFlow to do computation follows a slight different structure from traditional procedures programming using C, Java or Python. Instead of doing calculation along the execution of lines of programs, **TensorFlow is mainly composed of two parts: **
#
# 1. **building computaion steps, i.e. the graph**
# 2. **take in input values into the graph and generate results**

# %% [markdown]
# For example, if I have the python code below:

# %%
def formula1(a, b):
    return a * b * 2

def formula2(a, b):
    return a + b + 10

a = 1
b = 2
c = 3
d = 4

x = formula1(a, b)
y = formula1(c, d)
z = formula2(x, y)

print(x, y, z)
# Out:
# 4 24 38

# %% [markdown]
# Then when running, this program will perform the operations line by line. Specifically, when running at line 7, the variable "a" is assigned value 1, when running at line 12, the calculation of "formula1(a,b)" is computed and the variable "x" is assigned value 4. However in TensorFlow, all the calculation and value assignments will not be executed unless explicitly asked to. Otherwise only the calculation process will be formed, but values won't be passed in and calculation will not happen. Thus, I think a likely analog could be merging all the formulas into a big one and wait to be explicitly asked to do the computation. And the above program can be rewritten as follows to mimic TensorFlow structure:

# %%
def formula1(a, b):
    return a * b * 2

def formula2(a, b):
    return a + b + 10

# this is to mimic the explicit call to execute the calculation
def calculate(z):
    print(z)

# merge seperate formulas together to be one big complete formula
z = formula2(formula1(a, b), formula1(c, d))
# ==>
z = formula1(a,b) + formula1(c,d) + 10
# ==>
z = a * b * 2 + c * d * 2 + 10

a = 1
b = 2
c = 3
d = 4

# all the value assignments and calculations wait here to be executed

# ======================================================================

# explicitly issue to execution command, all the needed value assignments 
# and calculations in order to calculate "z" are traced back to and done.
# specifically, "z" traces back to how it is formed, and that calls the 
# "formula2" function. And since in this calculation "formula2" needs two 
# parameters which are "formula1(a,b)" and "formula1(c,d)", these two 
# calculations are traced to and executed before "formula2" got executed 
# to generate value of "z". And in order to calculate "formula1(a,b)" and 
# "formula1(c,d)", variable "a", "b", "c" and "d" are traced to and assigned 
# the values 1, 2, 3 and 4 before calculations are down.
calculate(z)
# Out:
# 38

# %% [markdown]
# ### 4.2 Graph

# %% [markdown]
# The name TensorFlow is a great concise and accurate description of its internal core structure of this framework. That is Tensors (any dimension of arrays) flowing within Graphs (a composition of nodes and edges where nodes represent computation operations and edges represent data flow) in order to realize certain computations.

# %% [markdown]
# #### 4.2.1 Tensor

# %% [markdown]
# Tensors, as roughly mentioned above, are the n-dimensional arrays flowing in the edges of a Graph. And it is worthwhile to mention that most TensorFlow functions return tf.Tensors.
#
# Here is an example of how to create simple constant Tensors:

# %%
a = tf.constant(1.0, dtype=tf.float32)
b = tf.constant(2.0) # dtype=tf.float32 implicitly
c = tf.constant(3, dtype=tf.int32)
d = tf.constant(4) # dtype=tf.int32 implicitly

# %% [markdown]
# As mentioned above, Tensors are not given values yet until being explicitly asked to. Thus, the are all empty values at this moment, which can be shown as follows:

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# Tensor("Const_1:0", shape=(), dtype=float32)
# Tensor("Const_2:0", shape=(), dtype=float32)
# Tensor("Const_3:0", shape=(), dtype=int32)
# Tensor("Const_4:0", shape=(), dtype=int32)

# %% [markdown]
# This shows that all the Tensors have value 0 instead of seemingly given values 1.0, 2.0, 3 and 4.

# %% [markdown]
# Also, Tensors can have any dimensions or ranks. See the following example:

# %%
e = tf.constant([1, 2, 3, 4]) # rank 1
f = tf.constant([[1, 2], [3, 4]]) # rank 2
g = tf.constant([[1], [2], [3], [4]]) # rank 2
h = tf.constant([[[1], [2]], [[3], [4]]]) # rank 3
print(e)
print(f)
print(g)
print(h)
# Out:
# Tensor("Const_5:0", shape=(4,), dtype=int32)
# Tensor("Const_6:0", shape=(2, 2), dtype=int32)
# Tensor("Const_7:0", shape=(4, 1), dtype=int32)
# Tensor("Const_8:0", shape=(2, 2, 1), dtype=int32)

# %% [markdown]
# As we can see from the "shape" parameter shown here, Tensors can be built very flexibly. Actually TensorFlow uses numpy arrays to represent Tensor values in Python. This enhances its convenience to use in large scale mathematical computations or machine learning tasks.

# %% [markdown]
# Obviously constant is far from enough to represent all the Tensors. So besides constants, TnesorFlow also provides other types of Tensors. Specifically they are:
# - tf.Variable
# - tf.constant
# - tf.placeholder
# - tf.SparseTensor

# %% [markdown]
# Specifically, placeholders are used to wait for external input which will be fed in later. Usage examples are shown below:

# %%
x = tf.placeholder(tf.float32)

# %% [markdown]
# This gives us one placeholder waiting for a floating point number.

# %% [markdown]
# tf.Variable is the only one among them whose value can be changed during the program running. In other word, all the other three types are immutable once assigned. To create a tf.Variable, it is recommended to use tf.get_variable method.

# %%
var = tf.get_variable("var", [1, 2, 3])

# %% [markdown]
# where the name and shape of the Variable is specified.

# %% [markdown]
# #### 4.2.2 Operation

# %% [markdown]
# Operations take Tensors as inputs, doing calculations with them and output results as Tensors. They make up the nodes of a graph. Common operations are like addition and multiplication, which are the most basic and widely used operations for machine learning tasks, especially in neural networks.

# %%
add = a + b
mul = c * d
print(add)
print(mul)
# Out:
# Tensor("add:0", shape=(), dtype=float32)
# Tensor("mul:0", shape=(), dtype=int32)

# %% [markdown]
# Since not explicitly asked to run yet, the operations are just built and ready to run.

# %% [markdown]
# ### 4.3 Session

# %% [markdown]
# Now we are finally here to explicit run the value assignments and computations. A Session object encapsulates the environment in which Operation objects are executed, and Tensor objects are evaluated. First of all, let's build a simple tf.Session.

# %%
sess = tf.Session()

# %% [markdown]
# Now let's try to use this session, an encapsulation in which Tensors flow through the Operations, to run the Operations built above.

# %%
print(sess.run(add))
print(sess.run(mul))
# Out:
# 3.0
# 12

# %% [markdown]
# It is worthwhile to mention that in order to calculate value for "add", only the "add" itself needs to be passed into tf.Session().run() and all the value assignments and calculations which are prerequisite for this "add" will be automatically figured out and get calculated beforehand.

# %% [markdown]
# ## 5. Realize Machine Learning using TensorFlow

# %% [markdown]
# Now we already have a basic understanding about how TensorFlow works essencially. In this section let's try to use the basic components we have presented to build a realization of a simple machine learning algorithm - linear regression - as well as TensorFlow's straight-forward high level methods directly.

# %% [markdown]
# ### 5.1 Low Level

# %% [markdown]
# First let's realize it using low level model components. See if the model can guess the mathmatical relation between my features and labels, i.e. y=x+1
#
# (Citation: https://www.tensorflow.org/programmers_guide/low_level_intro#training_1)

# %%
# First of all, let's build some constants as the data features 
# and labels used for training the model later.
x = tf.constant([[0], [1], [2], [3], [4], [5]], dtype=tf.float32)
y = tf.constant([[1], [2], [3], [4], [5], [6]], dtype=tf.float32)

# Then we employ the Layers, which is the interface of TensorFlow
# to build computing relations or nodes and edges. The tf.layers.Dense() 
# we use here is a densely connected layer class which takes in 
# input vectors and output a single value.
regressor = tf.layers.Dense(units=1)

# pass in features
predictions = regressor(x)

# choose loss function as MSE 
loss_function = tf.losses.mean_squared_error(labels=y, predictions=predictions)

# choose optimization method as gradient descent
# with learning rate 0.05
optimization = tf.train.GradientDescentOptimizer(0.05)

# build training process
training = optimization.minimize(loss_function)

# before running, simply run the internal initializer to initialize
# all the variables which cannot run otherwise
initialization = tf.global_variables_initializer()

# run TensorFlow Graph
sess = tf.Session()
sess.run(initialization)

# show prediction before training
# which is very much like random number
print("predict before training:")
print(sess.run(predictions))

# training with 1000 steps
for i in range(1000):
    sess.run((training, loss_function))

# show the final prediction after training
# which is very much the same as expected
print("predict after training:")
print(sess.run(predictions))
# Out:
# predict before training:
# [[ 0.        ]
#  [-0.22110462]
#  [-0.44220924]
#  [-0.66331387]
#  [-0.8844185 ]
#  [-1.1055231 ]]
# predict after training:
# [[0.9999988]
#  [1.9999992]
#  [2.9999995]
#  [3.9999998]
#  [5.       ]
#  [6.000001 ]]

# %% [markdown]
# ### 5.2 High Level

# %% [markdown]
# Then, let's realize the linear regression model using [tf.estimator.LinearRegressor](https://www.tensorflow.org/api_docs/python/tf/estimator/LinearRegressor) with exactly the same linear relation as the previous model.

# %%
import numpy as np

# Specify data for train, evaluate and predict new
train_x = {'x': np.array([1, 2, 3, 4, 5, 6, 7, 8])}
train_y = np.array([2, 3, 4, 5, 6, 7, 8, 9])
test_x = {'x': np.array([-1, -2, -3, -4])}
test_y = np.array([0, -1, -2, -3])
predict_x = {'x': np.array([16, 17, 18])}
predict_y = np.array([17, 18, 19])

# Create input functions.
def input_fn_train(features, labels, batch_size): 
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((features, labels))
    # Shuffle, repeat, and batch the examples.
    return dataset.shuffle(10).repeat().batch(batch_size)

def input_fn_evaluate(features, labels, batch_size): 
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((features, labels))
    # Batch the examples.
    return dataset.batch(batch_size)

def input_fn_predict(features, batch_size):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices(features)
    # Batch the examples.
    return dataset.batch(batch_size)
   

# Build feature columns.
feature_columns = [tf.feature_column.numeric_column(key='x')]

# Build BaselineRegressor.
regressor = tf.estimator.LinearRegressor(feature_columns=feature_columns)

# Fit model.
regressor.train(input_fn=lambda:input_fn_train(train_x, train_y, 3), steps=1000)

# Evaluate squared-loss between the test and train targets.
loss = regressor.evaluate(input_fn=lambda:input_fn_evaluate(test_x, test_y, 3))["loss"]

# Show evaluation result.
print("loss:", loss)

# Predict outputs the mean value seen during training.
predictions = regressor.predict(input_fn=lambda:input_fn_predict(predict_x, 3))

# Show prediction results.
template = ('\nPrediction is "{}", expected "{}"')
for pred, pred_y in zip(predictions, predict_y):
    print(template.format(pred["predictions"][0], pred_y))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpkr3_ndk5
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpkr3_ndk5', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f974e986a20>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpkr3_ndk5/model.ckpt.
# INFO:tensorflow:loss = 154.0, step = 1
# INFO:tensorflow:global_step/sec: 1217.32
# INFO:tensorflow:loss = 0.0051726485, step = 101 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1726.41
# INFO:tensorflow:loss = 0.0006789186, step = 201 (0.059 sec)
# INFO:tensorflow:global_step/sec: 1488.13
# INFO:tensorflow:loss = 0.000120204844, step = 301 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1711.63
# INFO:tensorflow:loss = 0.00034411432, step = 401 (0.057 sec)
# INFO:tensorflow:global_step/sec: 1781.42
# INFO:tensorflow:loss = 0.00035567867, step = 501 (0.057 sec)
# INFO:tensorflow:global_step/sec: 1617.29
# INFO:tensorflow:loss = 0.00016510204, step = 601 (0.061 sec)
# INFO:tensorflow:global_step/sec: 1818.62
# INFO:tensorflow:loss = 0.00014284728, step = 701 (0.055 sec)
# INFO:tensorflow:global_step/sec: 1782.41
# INFO:tensorflow:loss = 4.8418304e-05, step = 801 (0.056 sec)
# INFO:tensorflow:global_step/sec: 1896.16
# INFO:tensorflow:loss = 2.0499709e-05, step = 901 (0.053 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpkr3_ndk5/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8412667e-06.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-01-01:06:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpkr3_ndk5/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-01-01:06:22
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 4.7457404e-05, global_step = 1000, loss = 9.491481e-05
# loss: 9.491481e-05
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpkr3_ndk5/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Prediction is "16.99089813232422", expected "17"
#
# Prediction is "17.99003791809082", expected "18"
#
# Prediction is "18.989177703857422", expected "19"

# %% [markdown]
# ### 5.3 Summary
#
# Comparing the above two realizations, we can easily find that the high level Estimator is more structured. The steps are almost the same for different Estimators, hiding the complicated and variant details underneath. So the usage are more universal.
#
# **Generally speaking, using an Estimator follows these four steps:**
#
# 1. **Write one or more dataset importing functions.**
# 2. **Define the feature columns.**
# 3. **Instantiate the relevant pre-made Estimator.**
# 4. **Call a training, evaluation, or inference method.**

# %% [markdown]
# ## 6. Analysis of Real Dataset
#
# Having known how to build machine learning models with TensorFlow, now let's go a little further to analyze a real world dataset, called ["Pima Indians Diabetes Database"](https://www.kaggle.com/uciml/pima-indians-diabetes-database/data) from Kaggle.

# %% [markdown]
# ### 6.1 Dataset overview
#
# This dataset gives eight attributes of features together with the outcome whether this person has diabetes or not. All columns are numerical and there is no empty row anywhere. Now let's load this data in and have a look of it generally.

# %%
import pandas as pd

# Read data from csv file
diabetes = pd.read_csv("datasets/diabetes.csv")

# Show feature information
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ### 6.2 Generate features

# %% [markdown]
# #### 6.2.1 Generate features
#
# Let's split this dataset into training set and test set for later use. In order to spliting dataset propotionally to labels, i.e. to have generally identical percent of positive and negative labels in both sets, I will use the "train_test_split" function from scikit-learn library.

# %%
from sklearn.model_selection import train_test_split

# Stratify dataset into training set and test set
train,test=train_test_split(diabetes,test_size=0.25,random_state=0,stratify=diabetes['Outcome'])

# Generate features and labels
train_x, train_y = train, train.pop("Outcome")
test_x, test_y = test, test.pop("Outcome")

# %% [markdown]
# #### 6.2.2 Normalization
#
# Before we can start to apply different machine learning models on the data, we should first normalize the dataset, which would be greatly benefitial for increasing the accuracy.

# %%
# Normalize features
features = train_x.columns.values
for feature in features:
    mean, std = diabetes[feature].mean(), diabetes[feature].std()
    train_x.loc[:, feature] = (train_x[feature] - mean) / std
    test_x.loc[:, feature] = (test_x[feature] - mean) / std
    
# Display normalized training features
print(train_x)
# Out:
# /home/shuqih/ENTER/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 432    -0.844335 -1.279049       0.252871      -0.597814 -0.171805 -0.252732
# 453    -0.547562 -0.059255      -3.570271      -1.287373 -0.692439 -1.571832
# 706     1.826623 -0.184362      -3.570271      -1.287373 -0.692439 -4.057829
# 606    -0.844335  1.879904       0.459528       1.345490  1.849992  1.015634
# 118     0.045984 -0.747344      -0.470426       0.154433 -0.692439 -0.481038
# 421    -0.547562 -0.841174      -0.057113      -0.159003 -0.032969 -0.760078
# 3      -0.844335 -0.997558      -0.160441       0.154433  0.123221 -0.493721
# 157    -0.844335 -0.372022      -0.677082       0.029058  0.478988 -0.861547
# 400     0.045984 -0.809897      -0.263769      -1.287373 -0.692439  0.000941
# 497    -0.547562 -1.247772       0.149543      -0.347065 -0.032969 -0.240048
# 296    -0.547562  0.785218       0.046215       1.094741  2.431367 -0.506405
# 30      0.342757 -0.372022       0.304536       0.342494 -0.692439  0.508288
# 201    -0.844335  0.535004       0.666184      -1.287373 -0.692439  1.028318
# 314     0.936304 -0.372022       0.562856       0.655930 -0.692439  0.495604
# 32     -0.250789 -1.028834      -0.573754      -0.597814 -0.223868 -0.912282
# 475    -1.141108  0.503727       0.769512       0.405181 -0.692439 -0.595191
# 501    -0.250789 -1.153942       0.149543       0.718617 -0.692439  0.660492
# 293    -0.844335  0.222236      -1.090395       1.533551  0.990945  1.079052
# 681    -1.141108  1.285646       0.356200       0.969366 -0.692439  2.233265
# 381    -1.141108 -0.497129      -0.057113       0.091745 -0.692439 -1.521098
# 346    -0.844335  0.566280      -1.193723      -0.096316  0.027772 -0.417619
# 34      1.826623  0.034575       0.459528       0.655930 -0.692439 -0.557140
# 119     0.045984 -0.684790       0.356200      -0.347065 -0.249900 -1.115221
# 642     0.639530  0.816495       0.562856      -1.287373 -0.692439 -0.316150
# 248     1.529850  0.097129       0.046215       0.781305  2.795812  0.432186
# 397    -1.141108  0.316066      -0.160441       1.220115 -0.692439  0.292666
# 101    -0.844335  0.941602      -0.470426      -1.287373 -0.692439 -0.747395
# 645    -0.547562  1.129262       0.252871       0.906679  3.125547  0.939532
# 498     0.936304  2.317779       0.046215       0.781305  0.565761 -0.874231
# 659    -0.250789 -1.279049       0.666184       0.655930 -0.085032  0.279982
# ..           ...       ...            ...            ...       ...       ...
# 487    -1.141108  1.629690       0.459528       0.718617  1.607030  1.840072
# 749     0.639530  1.285646      -0.367098      -1.287373 -0.692439 -0.975700
# 622     0.639530  1.942458       1.286153      -1.287373 -0.692439  1.117103
# 458     1.826623  0.847771       0.769512       1.721613  1.364067  0.711226
# 45     -1.141108  1.848628      -0.160441       1.157428 -0.692439  1.269307
# 228     0.045984  2.380333       0.046215       1.157428  5.763428  0.597073
# 682    -1.141108 -0.809897      -0.263769       1.157428  0.218671  1.599082
# 359    -0.844335  2.349056       0.356200       0.969366  1.468194  0.571706
# 171     0.639530  0.409897       0.046215       0.154433  0.435602  0.432186
# 99     -0.844335  0.034575       1.079497       1.909674  1.216554  2.245949
# 593    -0.547562 -1.216495      -0.883738       0.091745  0.305443 -0.442987
# 49      0.936304 -0.497129      -3.570271      -1.287373 -0.692439 -4.057829
# 104    -0.547562 -1.122665      -0.212105      -1.287373 -0.692439  0.964899
# 370    -0.250789  1.629690       0.666184       1.721613  3.342478  0.812696
# 138    -1.141108  0.253513       0.562856      -1.287373 -0.692439 -0.100528
# 570    -0.250789 -1.341602       0.046215      -1.287373 -0.692439  0.064360
# 687    -0.844335 -0.434576      -0.987066      -0.096316 -0.692439 -0.468354
# 303     0.342757 -0.184362       1.492809      -1.287373 -0.692439  2.651826
# 51     -0.844335 -0.622237      -0.987066      -0.347065 -0.380059 -0.988384
# 221    -0.547562  1.160539       1.079497      -1.287373 -0.692439 -0.049793
# 583     1.233077 -0.653513       0.356200      -1.287373 -0.692439  0.850747
# 231     0.639530  0.409897       0.562856       1.032053  2.518140  1.802021
# 215     2.420169  0.941602       0.046215       1.220115  1.659093  1.243940
# 757    -1.141108  0.065852       0.149543      -1.287373 -0.692439  0.546339
# 657    -0.844335 -0.027978       0.562856       1.721613  1.043009  0.876114
# 628     0.342757  0.222236       0.562856      -1.287373 -0.692439  0.330716
# 456    -0.844335  0.441173      -0.780410      -1.287373 -0.692439 -0.671293
# 398    -0.250789 -1.216495       0.046215      -1.287373 -0.692439 -1.381577
# 378     0.045984  1.097985       0.304536      -1.287373 -0.692439  2.068378
# 294    -1.141108  1.254369      -0.987066      -1.287373 -0.692439 -1.280108
#
#      DiabetesPedigreeFunction       Age
# 432                  0.166372 -0.955839
# 453                  1.086908  3.295778
# 706                 -0.636457 -0.275580
# 606                  2.372641 -0.955839
# 118                 -0.087153 -0.955839
# 421                  0.268989 -1.040871
# 3                   -0.920163 -1.040871
# 157                  1.089926 -0.870806
# 400                 -0.938272 -0.190548
# 497                  0.226735 -0.700742
# 296                 -0.407077 -0.360612
# 30                   0.223717  2.275390
# 201                 -0.711910 -0.445645
# 314                  1.977263  0.829840
# 32                  -0.618348 -0.955839
# 475                 -0.727001  2.190358
# 501                 -0.618348 -0.445645
# 293                  0.425933 -0.785774
# 681                 -0.325587 -0.615709
# 381                 -0.711910 -0.955839
# 346                  0.549677 -0.955839
# 34                   0.121099  0.999905
# 119                 -0.751146 -1.040871
# 642                 -0.886963  1.425067
# 248                 -0.573076  0.064549
# 397                 -0.832637 -0.955839
# 101                 -0.883945 -0.955839
# 645                 -1.019762 -0.275580
# 498                 -0.932236  1.850228
# 659                  2.475258 -0.530677
# ..                        ...       ...
# 487                  2.073844  2.105325
# 749                 -0.886963  1.425067
# 622                  2.985325  0.999905
# 458                  1.596976  1.510099
# 45                   4.289167 -0.700742
# 228                  5.605081 -0.190548
# 682                 -0.319551 -0.955839
# 359                  1.216689 -0.360612
# 171                  0.211644 -0.360612
# 99                  -0.443295 -0.190548
# 593                  3.703646 -0.700742
# 49                  -0.503658 -0.785774
# 104                  1.382687 -0.530677
# 370                  5.025596 -0.700742
# 138                  0.697566 -0.360612
# 570                 -0.609293  0.489711
# 687                 -0.877909 -0.360612
# 303                 -0.793401 -0.445645
# 51                   0.163354 -0.615709
# 221                  1.005418  2.785584
# 583                 -0.850745  0.744808
# 231                 -0.705874  1.084937
# 215                  0.815274  0.404679
# 757                 -0.645511  1.595131
# 657                  2.082898  0.659776
# 628                 -0.989580  0.999905
# 456                  0.649276  2.445455
# 398                 -0.250133 -0.700742
# 378                 -0.705874 -0.105515
# 294                 -0.657584  2.700552
#
# [576 rows x 8 columns]

# %% [markdown]
# ### 6.3 Analyze with Logistic Regression
#
# First of all, since this is a binary classification problem and the number of features is not very big, we can try to start with simple linear model which could be a great choice for such a problem. Let's build a linear classifier - [tf.estimator.LinearClassifier](https://www.tensorflow.org/api_docs/python/tf/estimator/LinearClassifier) - step by step.

# %% [markdown]
# #### 6.3.1 Create input function
#
# Input functions are used to feed data for the machine learning model. It returns [tf.data.Dataset](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) objects which is TensorFlow's standard interface for building data pipeline.

# %%
def input_fn_train(features, labels, batch_size): 
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    # Shuffle, repeat, and batch the examples.
    return dataset.shuffle(10).repeat().batch(batch_size)

def input_fn_evaluate(features, labels, batch_size): 
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    # Batch the examples.
    return dataset.batch(batch_size)

def input_fn_predict(features, batch_size):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices(dict(features))
    # Batch the examples.
    return dataset.batch(batch_size)

# %% [markdown]
# #### 6.3.2 Define the feature columns
#
# There is actually much more to say about feature columns. Because sttributes of datasets can have many more types than just numerical data in this example. For example categorical data and strings. In order to coping with those data types, more complicated steps are needed to build feature columns which are suitable of inputing into the machine learning model. That is because machine learning models can only compute upon numerical values. Please check [this short introduction](https://www.tensorflow.org/get_started/feature_columns) if you wonder how to change other data types into usable numerical representations.

# %%
# Generate feature columns
feature_columns = []
for key in train_x.keys():
    feature_columns.append(tf.feature_column.numeric_column(key=key))
print(feature_columns)
# Out:
# [_NumericColumn(key='Pregnancies', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='Glucose', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='BloodPressure', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='SkinThickness', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='Insulin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='BMI', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='DiabetesPedigreeFunction', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# #### 6.3.3 Instantiate an estimator
#
# Let's build a logistic regression model by emplying TensorFlow's high level Estimator - tf.estimator.LinearClassifier.

# %%
# Instantiate a tf.estimator.LinearClassifier
classifier = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpxx7el52b
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpxx7el52b', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f974ea70080>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# #### 6.3.4 Train, evaluate and predict
#
# Now we train the model and evaluate it on the test set, showing you the overall accuracy as well as prediction for each sample.

# %%
# Train the model
classifier.train(input_fn=lambda:input_fn_train(train_x, train_y, 100), steps=1000)

# Evaluate the model
accuracy = classifier.evaluate(input_fn=lambda:input_fn_evaluate(test_x, test_y, 100))
# Display accuracy on test set
print('\nTest set accuracy: {accuracy:0.4f}\n'.format(**accuracy))

# Predict on test set
predictions = classifier.predict(input_fn=lambda:input_fn_predict(test_x, 100))
# Display predictions for each row in test set
template = ('\nPrediction is "{}" ({:.2f}%), expectation is "{}"')
for prediction, expectation in zip(predictions, test_y):
    predicted_class = prediction['class_ids'][0]
    probability = prediction['probabilities'][predicted_class]
    print(template.format(predicted_class, 100 * probability, expectation))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpxx7el52b/model.ckpt.
# INFO:tensorflow:loss = 69.31472, step = 1
# INFO:tensorflow:global_step/sec: 565.058
# INFO:tensorflow:loss = 52.21797, step = 101 (0.178 sec)
# INFO:tensorflow:global_step/sec: 831.542
# INFO:tensorflow:loss = 47.386295, step = 201 (0.120 sec)
# INFO:tensorflow:global_step/sec: 845.682
# INFO:tensorflow:loss = 44.51356, step = 301 (0.119 sec)
# INFO:tensorflow:global_step/sec: 858.909
# INFO:tensorflow:loss = 44.894844, step = 401 (0.116 sec)
# INFO:tensorflow:global_step/sec: 819.458
# INFO:tensorflow:loss = 45.265926, step = 501 (0.122 sec)
# INFO:tensorflow:global_step/sec: 831.848
# INFO:tensorflow:loss = 41.730698, step = 601 (0.120 sec)
# INFO:tensorflow:global_step/sec: 867.267
# INFO:tensorflow:loss = 43.093513, step = 701 (0.115 sec)
# INFO:tensorflow:global_step/sec: 838.921
# INFO:tensorflow:loss = 55.46201, step = 801 (0.119 sec)
# INFO:tensorflow:global_step/sec: 781.709
# INFO:tensorflow:loss = 53.307858, step = 901 (0.130 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpxx7el52b/model.ckpt.
# INFO:tensorflow:Loss for final step: 48.019737.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-01-01:06:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxx7el52b/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-01-01:06:27
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.78125, accuracy_baseline = 0.6510416, auc = 0.87194026, auc_precision_recall = 0.7585821, average_loss = 0.4344593, global_step = 1000, label/mean = 0.34895834, loss = 41.70809, prediction/mean = 0.346109
#
# Test set accuracy: 0.7812
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxx7el52b/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Prediction is "0" (68.82%), expectation is "0"
#
# Prediction is "0" (90.06%), expectation is "0"
#
# Prediction is "0" (84.73%), expectation is "0"
#
# Prediction is "0" (87.85%), expectation is "0"
#
# Prediction is "0" (88.30%), expectation is "0"
#
# Prediction is "1" (55.25%), expectation is "0"
#
# Prediction is "1" (65.70%), expectation is "1"
#
# Prediction is "0" (78.39%), expectation is "1"
#
# Prediction is "1" (65.51%), expectation is "0"
#
# Prediction is "0" (73.41%), expectation is "1"
#
# Prediction is "1" (69.67%), expectation is "0"
#
# Prediction is "0" (81.48%), expectation is "1"
#
# Prediction is "1" (69.96%), expectation is "1"
#
# Prediction is "1" (78.47%), expectation is "1"
#
# Prediction is "0" (97.90%), expectation is "0"
#
# Prediction is "0" (53.35%), expectation is "0"
#
# Prediction is "0" (82.89%), expectation is "0"
#
# Prediction is "0" (86.81%), expectation is "0"
#
# Prediction is "0" (67.04%), expectation is "0"
#
# Prediction is "0" (96.62%), expectation is "0"
#
# Prediction is "1" (74.81%), expectation is "0"
#
# Prediction is "0" (64.97%), expectation is "1"
#
# Prediction is "0" (82.15%), expectation is "0"
#
# Prediction is "0" (81.44%), expectation is "0"
#
# Prediction is "0" (93.70%), expectation is "0"
#
# Prediction is "0" (99.40%), expectation is "0"
#
# Prediction is "0" (94.03%), expectation is "0"
#
# Prediction is "0" (96.56%), expectation is "0"
#
# Prediction is "0" (67.26%), expectation is "1"
#
# Prediction is "0" (84.62%), expectation is "0"
#
# Prediction is "0" (80.74%), expectation is "0"
#
# Prediction is "0" (75.23%), expectation is "1"
#
# Prediction is "1" (74.10%), expectation is "0"
#
# Prediction is "0" (76.45%), expectation is "0"
#
# Prediction is "1" (63.84%), expectation is "1"
#
# Prediction is "1" (83.61%), expectation is "1"
#
# Prediction is "0" (95.96%), expectation is "0"
#
# Prediction is "0" (93.22%), expectation is "0"
#
# Prediction is "0" (93.34%), expectation is "0"
#
# Prediction is "0" (86.78%), expectation is "0"
#
# Prediction is "0" (58.50%), expectation is "0"
#
# Prediction is "1" (64.32%), expectation is "0"
#
# Prediction is "1" (93.79%), expectation is "1"
#
# Prediction is "1" (75.16%), expectation is "1"
#
# Prediction is "0" (89.22%), expectation is "0"
#
# Prediction is "1" (73.64%), expectation is "1"
#
# Prediction is "1" (59.93%), expectation is "1"
#
# Prediction is "0" (86.69%), expectation is "0"
#
# Prediction is "1" (84.83%), expectation is "1"
#
# Prediction is "1" (84.71%), expectation is "1"
#
# Prediction is "0" (88.79%), expectation is "0"
#
# Prediction is "1" (76.12%), expectation is "1"
#
# Prediction is "0" (67.03%), expectation is "0"
#
# Prediction is "0" (55.38%), expectation is "0"
#
# Prediction is "0" (90.59%), expectation is "0"
#
# Prediction is "1" (66.69%), expectation is "1"
#
# Prediction is "0" (86.44%), expectation is "0"
#
# Prediction is "0" (53.92%), expectation is "0"
#
# Prediction is "0" (50.00%), expectation is "0"
#
# Prediction is "0" (92.89%), expectation is "0"
#
# Prediction is "0" (72.25%), expectation is "1"
#
# Prediction is "0" (69.87%), expectation is "0"
#
# Prediction is "0" (63.17%), expectation is "1"
#
# Prediction is "0" (83.98%), expectation is "0"
#
# Prediction is "0" (55.22%), expectation is "1"
#
# Prediction is "1" (62.74%), expectation is "0"
#
# Prediction is "0" (65.62%), expectation is "0"
#
# Prediction is "1" (73.37%), expectation is "1"
#
# Prediction is "0" (53.00%), expectation is "1"
#
# Prediction is "1" (80.56%), expectation is "1"
#
# Prediction is "0" (74.15%), expectation is "0"
#
# Prediction is "0" (57.34%), expectation is "1"
#
# Prediction is "0" (91.76%), expectation is "0"
#
# Prediction is "0" (71.18%), expectation is "0"
#
# Prediction is "1" (77.33%), expectation is "1"
#
# Prediction is "0" (90.32%), expectation is "0"
#
# Prediction is "0" (80.06%), expectation is "0"
#
# Prediction is "0" (87.89%), expectation is "0"
#
# Prediction is "0" (86.46%), expectation is "0"
#
# Prediction is "0" (82.44%), expectation is "0"
#
# Prediction is "1" (67.43%), expectation is "1"
#
# Prediction is "0" (52.46%), expectation is "1"
#
# Prediction is "1" (78.04%), expectation is "0"
#
# Prediction is "0" (77.09%), expectation is "1"
#
# Prediction is "0" (88.25%), expectation is "0"
#
# Prediction is "1" (66.33%), expectation is "1"
#
# Prediction is "0" (90.17%), expectation is "0"
#
# Prediction is "1" (76.31%), expectation is "1"
#
# Prediction is "0" (92.34%), expectation is "0"
#
# Prediction is "0" (89.82%), expectation is "0"
#
# Prediction is "0" (96.06%), expectation is "0"
#
# Prediction is "0" (77.80%), expectation is "1"
#
# Prediction is "1" (50.59%), expectation is "1"
#
# Prediction is "0" (92.45%), expectation is "0"
#
# Prediction is "0" (78.34%), expectation is "0"
#
# Prediction is "0" (89.70%), expectation is "0"
#
# Prediction is "0" (76.82%), expectation is "0"
#
# Prediction is "0" (74.69%), expectation is "0"
#
# Prediction is "0" (92.88%), expectation is "0"
#
# Prediction is "0" (85.61%), expectation is "0"
#
# Prediction is "0" (84.57%), expectation is "0"
#
# Prediction is "0" (77.42%), expectation is "1"
#
# Prediction is "0" (89.36%), expectation is "0"
#
# Prediction is "0" (51.47%), expectation is "1"
#
# Prediction is "0" (87.25%), expectation is "1"
#
# Prediction is "1" (79.89%), expectation is "1"
#
# Prediction is "0" (98.91%), expectation is "0"
#
# Prediction is "0" (62.89%), expectation is "1"
#
# Prediction is "1" (65.28%), expectation is "1"
#
# Prediction is "0" (68.39%), expectation is "0"
#
# Prediction is "0" (90.85%), expectation is "0"
#
# Prediction is "0" (97.09%), expectation is "0"
#
# Prediction is "0" (98.30%), expectation is "0"
#
# Prediction is "0" (92.04%), expectation is "0"
#
# Prediction is "0" (51.46%), expectation is "0"
#
# Prediction is "1" (96.08%), expectation is "1"
#
# Prediction is "1" (89.23%), expectation is "1"
#
# Prediction is "0" (55.71%), expectation is "1"
#
# Prediction is "0" (61.31%), expectation is "0"
#
# Prediction is "1" (76.60%), expectation is "1"
#
# Prediction is "0" (91.85%), expectation is "0"
#
# Prediction is "1" (64.86%), expectation is "1"
#
# Prediction is "0" (94.61%), expectation is "0"
#
# Prediction is "0" (56.28%), expectation is "0"
#
# Prediction is "1" (87.30%), expectation is "1"
#
# Prediction is "0" (61.56%), expectation is "0"
#
# Prediction is "0" (58.40%), expectation is "0"
#
# Prediction is "0" (74.71%), expectation is "0"
#
# Prediction is "0" (96.70%), expectation is "0"
#
# Prediction is "1" (79.80%), expectation is "1"
#
# Prediction is "0" (81.45%), expectation is "0"
#
# Prediction is "0" (83.04%), expectation is "1"
#
# Prediction is "0" (70.30%), expectation is "0"
#
# Prediction is "1" (92.61%), expectation is "0"
#
# Prediction is "0" (86.00%), expectation is "0"
#
# Prediction is "0" (88.04%), expectation is "0"
#
# Prediction is "0" (95.77%), expectation is "0"
#
# Prediction is "1" (79.78%), expectation is "1"
#
# Prediction is "0" (88.44%), expectation is "0"
#
# Prediction is "0" (58.89%), expectation is "1"
#
# Prediction is "0" (71.46%), expectation is "0"
#
# Prediction is "0" (94.90%), expectation is "0"
#
# Prediction is "1" (64.60%), expectation is "1"
#
# Prediction is "0" (90.22%), expectation is "0"
#
# Prediction is "0" (70.37%), expectation is "1"
#
# Prediction is "0" (97.05%), expectation is "0"
#
# Prediction is "0" (82.33%), expectation is "0"
#
# Prediction is "1" (82.97%), expectation is "0"
#
# Prediction is "1" (84.81%), expectation is "1"
#
# Prediction is "1" (88.73%), expectation is "1"
#
# Prediction is "0" (95.17%), expectation is "0"
#
# Prediction is "0" (90.76%), expectation is "0"
#
# Prediction is "1" (72.27%), expectation is "1"
#
# Prediction is "1" (70.99%), expectation is "0"
#
# Prediction is "0" (90.50%), expectation is "0"
#
# Prediction is "0" (67.82%), expectation is "1"
#
# Prediction is "0" (78.13%), expectation is "0"
#
# Prediction is "0" (95.93%), expectation is "0"
#
# Prediction is "1" (50.09%), expectation is "1"
#
# Prediction is "0" (86.49%), expectation is "0"
#
# Prediction is "1" (68.68%), expectation is "0"
#
# Prediction is "0" (87.78%), expectation is "0"
#
# Prediction is "0" (74.47%), expectation is "0"
#
# Prediction is "0" (85.41%), expectation is "0"
#
# Prediction is "0" (60.15%), expectation is "1"
#
# Prediction is "0" (85.52%), expectation is "0"
#
# Prediction is "0" (77.37%), expectation is "0"
#
# Prediction is "1" (57.72%), expectation is "0"
#
# Prediction is "1" (87.90%), expectation is "1"
#
# Prediction is "0" (96.43%), expectation is "0"
#
# Prediction is "0" (59.78%), expectation is "1"
#
# Prediction is "1" (90.82%), expectation is "1"
#
# Prediction is "0" (94.73%), expectation is "0"
#
# Prediction is "1" (73.78%), expectation is "0"
#
# Prediction is "0" (67.12%), expectation is "1"
#
# Prediction is "0" (88.16%), expectation is "0"
#
# Prediction is "1" (83.51%), expectation is "1"
#
# Prediction is "0" (77.22%), expectation is "0"
#
# Prediction is "0" (84.81%), expectation is "0"
#
# Prediction is "0" (90.63%), expectation is "0"
#
# Prediction is "0" (90.60%), expectation is "1"
#
# Prediction is "0" (96.70%), expectation is "0"
#
# Prediction is "0" (95.91%), expectation is "0"
#
# Prediction is "0" (84.09%), expectation is "0"
#
# Prediction is "0" (94.45%), expectation is "0"
#
# Prediction is "0" (89.92%), expectation is "0"
#
# Prediction is "0" (55.65%), expectation is "1"
#
# Prediction is "1" (87.46%), expectation is "1"
#
# Prediction is "0" (80.90%), expectation is "0"
#
# Prediction is "0" (91.55%), expectation is "0"
#
# Prediction is "0" (95.62%), expectation is "0"
#
# Prediction is "1" (87.98%), expectation is "1"

# %% [markdown]
# ### 6.4 Analyze with Neural Network
#
# TensorFlow is especially suitable for building neural networks. Let's have a look of what a neural network is and how to build a [Deep Neural Network](https://www.tensorflow.org/api_docs/python/tf/estimator/DNNClassifier) for analyzing this problem.

# %% [markdown]
# #### 6.4.1 What Is Neural Network

# %% [markdown]
# Neural Network has the advantage of fitting a non-linear model without manual adjustment. When the data distribution gets too complex for people to figure out a suitable distribution model intuitively, neural network becomes one of the top solutions here.
#
# Specifically, instead of building a set of linear relations from the inputs to the outputs, neural network takes in several hidden layers in the middle that apply extra linear and non-linear mappings, thus using a network of small neurons to form the whole mathemitical model. The following picture show a dense neural network where dense means edges exists among any pair of nodes in the adjecent layers, i.e. the network is fully connected.
#
# ![title](images/NeuralNetwork.jpg)
#
# (Citation: https://www.tutorialspoint.com/artificial_intelligence/artificial_intelligence_neural_networks.htm)
#
# For more information about neural network a possible reference could be [Google's machine learning crash course](https://developers.google.com/machine-learning/crash-course/introduction-to-neural-networks/video-lecture).

# %% [markdown]
# #### 6.4.2 Create input function & Define the feature columns

# %% [markdown]
# I will just reuse the input functions and feature columns from the previous section for convenience since they are totally the same actually. This is also to show you how convenient and decoupled it is when building machine learning models with TensorFlow. Other components can be totally seperated from specific models.

# %% [markdown]
# #### 6.4.3 Instantiate an estimator
#
# Let's build a logistic regression model by emplying TensorFlow's high level Estimator - tf.estimator.DNNClassifier.

# %%
# Instantiate a tf.estimator.DNNClassifier with two hidden layers, each layer has 10 neurons
classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns, hidden_units=[10, 10])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp4iffnbo2
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp4iffnbo2', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f974d1c4ac8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# #### 6.4.4 Train, evaluate and predict
#
# This part is actually exactly the same as in the previous section. I put it here again for rendering the results as well as proving again how abstract Estimators are, i.e. all the processes of running an Estimator for whatever model is almost the same.

# %%
# Train the model
classifier.train(input_fn=lambda:input_fn_train(train_x, train_y, 100), steps=1000)

# Evaluate the model
accuracy = classifier.evaluate(input_fn=lambda:input_fn_evaluate(test_x, test_y, 100))
# Display accuracy on test set
print('\nTest set accuracy: {accuracy:0.4f}\n'.format(**accuracy))

# Predict on test set
predictions = classifier.predict(input_fn=lambda:input_fn_predict(test_x, 100))
# Display predictions for each row in test set
template = ('\nPrediction is "{}" ({:.2f}%), expectation is "{}"')
for prediction, expectation in zip(predictions, test_y):
    predicted_class = prediction['class_ids'][0]
    probability = prediction['probabilities'][predicted_class]
    print(template.format(predicted_class, 100 * probability, expectation))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp4iffnbo2/model.ckpt.
# INFO:tensorflow:loss = 71.36633, step = 1
# INFO:tensorflow:global_step/sec: 292.797
# INFO:tensorflow:loss = 48.79496, step = 101 (0.342 sec)
# INFO:tensorflow:global_step/sec: 376.322
# INFO:tensorflow:loss = 41.43766, step = 201 (0.266 sec)
# INFO:tensorflow:global_step/sec: 452.138
# INFO:tensorflow:loss = 37.242096, step = 301 (0.222 sec)
# INFO:tensorflow:global_step/sec: 566.498
# INFO:tensorflow:loss = 37.52878, step = 401 (0.176 sec)
# INFO:tensorflow:global_step/sec: 385.537
# INFO:tensorflow:loss = 34.027893, step = 501 (0.259 sec)
# INFO:tensorflow:global_step/sec: 781.113
# INFO:tensorflow:loss = 35.76065, step = 601 (0.128 sec)
# INFO:tensorflow:global_step/sec: 789.638
# INFO:tensorflow:loss = 40.656296, step = 701 (0.127 sec)
# INFO:tensorflow:global_step/sec: 777.211
# INFO:tensorflow:loss = 39.41826, step = 801 (0.129 sec)
# INFO:tensorflow:global_step/sec: 780.876
# INFO:tensorflow:loss = 45.491566, step = 901 (0.128 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp4iffnbo2/model.ckpt.
# INFO:tensorflow:Loss for final step: 36.42282.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-01-01:06:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp4iffnbo2/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-01-01:06:32
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.8072917, accuracy_baseline = 0.6510416, auc = 0.8518806, auc_precision_recall = 0.72577405, average_loss = 0.47816518, global_step = 1000, label/mean = 0.34895834, loss = 45.90386, prediction/mean = 0.35966495
#
# Test set accuracy: 0.8073
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp4iffnbo2/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Prediction is "0" (65.28%), expectation is "0"
#
# Prediction is "0" (99.35%), expectation is "0"
#
# Prediction is "0" (58.56%), expectation is "0"
#
# Prediction is "0" (95.31%), expectation is "0"
#
# Prediction is "0" (94.52%), expectation is "0"
#
# Prediction is "1" (92.22%), expectation is "0"
#
# Prediction is "1" (77.04%), expectation is "1"
#
# Prediction is "0" (88.01%), expectation is "1"
#
# Prediction is "1" (72.19%), expectation is "0"
#
# Prediction is "0" (60.14%), expectation is "1"
#
# Prediction is "1" (74.25%), expectation is "0"
#
# Prediction is "0" (74.38%), expectation is "1"
#
# Prediction is "1" (83.30%), expectation is "1"
#
# Prediction is "1" (95.52%), expectation is "1"
#
# Prediction is "0" (98.35%), expectation is "0"
#
# Prediction is "1" (55.71%), expectation is "0"
#
# Prediction is "0" (77.02%), expectation is "0"
#
# Prediction is "1" (57.21%), expectation is "0"
#
# Prediction is "1" (76.16%), expectation is "0"
#
# Prediction is "0" (99.50%), expectation is "0"
#
# Prediction is "1" (95.42%), expectation is "0"
#
# Prediction is "0" (68.65%), expectation is "1"
#
# Prediction is "0" (89.04%), expectation is "0"
#
# Prediction is "0" (90.57%), expectation is "0"
#
# Prediction is "0" (98.06%), expectation is "0"
#
# Prediction is "0" (99.89%), expectation is "0"
#
# Prediction is "0" (98.54%), expectation is "0"
#
# Prediction is "0" (99.29%), expectation is "0"
#
# Prediction is "0" (73.76%), expectation is "1"
#
# Prediction is "0" (82.44%), expectation is "0"
#
# Prediction is "0" (70.11%), expectation is "0"
#
# Prediction is "0" (94.61%), expectation is "1"
#
# Prediction is "0" (51.92%), expectation is "0"
#
# Prediction is "0" (97.99%), expectation is "0"
#
# Prediction is "1" (95.94%), expectation is "1"
#
# Prediction is "1" (86.82%), expectation is "1"
#
# Prediction is "0" (93.88%), expectation is "0"
#
# Prediction is "0" (98.71%), expectation is "0"
#
# Prediction is "0" (98.54%), expectation is "0"
#
# Prediction is "0" (93.84%), expectation is "0"
#
# Prediction is "1" (56.58%), expectation is "0"
#
# Prediction is "0" (84.73%), expectation is "0"
#
# Prediction is "1" (99.30%), expectation is "1"
#
# Prediction is "1" (78.72%), expectation is "1"
#
# Prediction is "0" (91.95%), expectation is "0"
#
# Prediction is "1" (87.70%), expectation is "1"
#
# Prediction is "1" (69.84%), expectation is "1"
#
# Prediction is "0" (98.60%), expectation is "0"
#
# Prediction is "1" (70.31%), expectation is "1"
#
# Prediction is "1" (69.32%), expectation is "1"
#
# Prediction is "0" (93.55%), expectation is "0"
#
# Prediction is "1" (60.36%), expectation is "1"
#
# Prediction is "0" (74.18%), expectation is "0"
#
# Prediction is "0" (74.89%), expectation is "0"
#
# Prediction is "0" (95.65%), expectation is "0"
#
# Prediction is "1" (71.04%), expectation is "1"
#
# Prediction is "0" (73.79%), expectation is "0"
#
# Prediction is "1" (62.27%), expectation is "0"
#
# Prediction is "0" (68.93%), expectation is "0"
#
# Prediction is "0" (85.47%), expectation is "0"
#
# Prediction is "0" (91.43%), expectation is "1"
#
# Prediction is "0" (60.32%), expectation is "0"
#
# Prediction is "1" (52.58%), expectation is "1"
#
# Prediction is "0" (97.90%), expectation is "0"
#
# Prediction is "1" (64.20%), expectation is "1"
#
# Prediction is "1" (75.47%), expectation is "0"
#
# Prediction is "0" (59.38%), expectation is "0"
#
# Prediction is "1" (75.47%), expectation is "1"
#
# Prediction is "1" (79.87%), expectation is "1"
#
# Prediction is "1" (94.22%), expectation is "1"
#
# Prediction is "0" (96.44%), expectation is "0"
#
# Prediction is "1" (60.58%), expectation is "1"
#
# Prediction is "0" (98.78%), expectation is "0"
#
# Prediction is "0" (73.77%), expectation is "0"
#
# Prediction is "1" (72.27%), expectation is "1"
#
# Prediction is "0" (98.83%), expectation is "0"
#
# Prediction is "0" (85.08%), expectation is "0"
#
# Prediction is "0" (99.49%), expectation is "0"
#
# Prediction is "0" (90.55%), expectation is "0"
#
# Prediction is "0" (91.67%), expectation is "0"
#
# Prediction is "1" (64.11%), expectation is "1"
#
# Prediction is "1" (63.77%), expectation is "1"
#
# Prediction is "1" (57.16%), expectation is "0"
#
# Prediction is "0" (80.52%), expectation is "1"
#
# Prediction is "0" (95.79%), expectation is "0"
#
# Prediction is "1" (63.28%), expectation is "1"
#
# Prediction is "0" (94.60%), expectation is "0"
#
# Prediction is "1" (93.09%), expectation is "1"
#
# Prediction is "0" (96.28%), expectation is "0"
#
# Prediction is "0" (94.71%), expectation is "0"
#
# Prediction is "0" (61.57%), expectation is "0"
#
# Prediction is "0" (70.03%), expectation is "1"
#
# Prediction is "1" (72.60%), expectation is "1"
#
# Prediction is "0" (97.81%), expectation is "0"
#
# Prediction is "0" (80.93%), expectation is "0"
#
# Prediction is "1" (61.30%), expectation is "0"
#
# Prediction is "0" (50.17%), expectation is "0"
#
# Prediction is "0" (83.07%), expectation is "0"
#
# Prediction is "0" (94.04%), expectation is "0"
#
# Prediction is "0" (91.69%), expectation is "0"
#
# Prediction is "0" (91.02%), expectation is "0"
#
# Prediction is "0" (90.13%), expectation is "1"
#
# Prediction is "0" (98.22%), expectation is "0"
#
# Prediction is "0" (90.44%), expectation is "1"
#
# Prediction is "0" (93.48%), expectation is "1"
#
# Prediction is "1" (95.10%), expectation is "1"
#
# Prediction is "0" (97.87%), expectation is "0"
#
# Prediction is "0" (89.96%), expectation is "1"
#
# Prediction is "1" (78.78%), expectation is "1"
#
# Prediction is "1" (54.63%), expectation is "0"
#
# Prediction is "0" (97.86%), expectation is "0"
#
# Prediction is "0" (99.61%), expectation is "0"
#
# Prediction is "0" (99.42%), expectation is "0"
#
# Prediction is "0" (98.16%), expectation is "0"
#
# Prediction is "0" (71.52%), expectation is "0"
#
# Prediction is "1" (90.30%), expectation is "1"
#
# Prediction is "1" (87.52%), expectation is "1"
#
# Prediction is "1" (92.63%), expectation is "1"
#
# Prediction is "0" (50.93%), expectation is "0"
#
# Prediction is "1" (98.26%), expectation is "1"
#
# Prediction is "0" (97.98%), expectation is "0"
#
# Prediction is "1" (79.00%), expectation is "1"
#
# Prediction is "0" (98.97%), expectation is "0"
#
# Prediction is "0" (55.06%), expectation is "0"
#
# Prediction is "1" (93.80%), expectation is "1"
#
# Prediction is "0" (56.34%), expectation is "0"
#
# Prediction is "1" (63.06%), expectation is "0"
#
# Prediction is "0" (81.45%), expectation is "0"
#
# Prediction is "0" (98.81%), expectation is "0"
#
# Prediction is "1" (68.68%), expectation is "1"
#
# Prediction is "0" (91.74%), expectation is "0"
#
# Prediction is "0" (82.31%), expectation is "1"
#
# Prediction is "0" (77.45%), expectation is "0"
#
# Prediction is "1" (97.79%), expectation is "0"
#
# Prediction is "0" (99.30%), expectation is "0"
#
# Prediction is "0" (94.38%), expectation is "0"
#
# Prediction is "0" (98.95%), expectation is "0"
#
# Prediction is "1" (84.77%), expectation is "1"
#
# Prediction is "0" (90.13%), expectation is "0"
#
# Prediction is "0" (57.76%), expectation is "1"
#
# Prediction is "1" (57.85%), expectation is "0"
#
# Prediction is "0" (98.46%), expectation is "0"
#
# Prediction is "1" (94.39%), expectation is "1"
#
# Prediction is "0" (98.86%), expectation is "0"
#
# Prediction is "0" (91.41%), expectation is "1"
#
# Prediction is "0" (99.06%), expectation is "0"
#
# Prediction is "0" (80.68%), expectation is "0"
#
# Prediction is "1" (82.79%), expectation is "0"
#
# Prediction is "1" (85.16%), expectation is "1"
#
# Prediction is "1" (93.65%), expectation is "1"
#
# Prediction is "0" (98.25%), expectation is "0"
#
# Prediction is "0" (97.63%), expectation is "0"
#
# Prediction is "1" (51.49%), expectation is "1"
#
# Prediction is "0" (62.53%), expectation is "0"
#
# Prediction is "0" (98.55%), expectation is "0"
#
# Prediction is "1" (52.15%), expectation is "1"
#
# Prediction is "0" (73.09%), expectation is "0"
#
# Prediction is "0" (98.70%), expectation is "0"
#
# Prediction is "1" (63.32%), expectation is "1"
#
# Prediction is "0" (91.63%), expectation is "0"
#
# Prediction is "1" (92.89%), expectation is "0"
#
# Prediction is "0" (82.62%), expectation is "0"
#
# Prediction is "0" (85.86%), expectation is "0"
#
# Prediction is "0" (84.29%), expectation is "0"
#
# Prediction is "1" (54.18%), expectation is "1"
#
# Prediction is "0" (85.02%), expectation is "0"
#
# Prediction is "0" (83.07%), expectation is "0"
#
# Prediction is "1" (77.51%), expectation is "0"
#
# Prediction is "1" (81.13%), expectation is "1"
#
# Prediction is "0" (99.59%), expectation is "0"
#
# Prediction is "1" (72.67%), expectation is "1"
#
# Prediction is "1" (70.42%), expectation is "1"
#
# Prediction is "0" (99.04%), expectation is "0"
#
# Prediction is "1" (86.21%), expectation is "0"
#
# Prediction is "1" (66.92%), expectation is "1"
#
# Prediction is "0" (94.03%), expectation is "0"
#
# Prediction is "1" (93.97%), expectation is "1"
#
# Prediction is "0" (96.99%), expectation is "0"
#
# Prediction is "0" (90.01%), expectation is "0"
#
# Prediction is "0" (98.73%), expectation is "0"
#
# Prediction is "0" (96.26%), expectation is "1"
#
# Prediction is "0" (99.55%), expectation is "0"
#
# Prediction is "0" (99.17%), expectation is "0"
#
# Prediction is "0" (96.02%), expectation is "0"
#
# Prediction is "0" (98.36%), expectation is "0"
#
# Prediction is "0" (98.10%), expectation is "0"
#
# Prediction is "1" (68.31%), expectation is "1"
#
# Prediction is "1" (97.06%), expectation is "1"
#
# Prediction is "0" (52.78%), expectation is "0"
#
# Prediction is "0" (86.07%), expectation is "0"
#
# Prediction is "0" (99.56%), expectation is "0"
#
# Prediction is "1" (92.05%), expectation is "1"

# %% [markdown]
# ### 6.5 Summary
#
# From the results above, we can find that Logistic Regression performs well on this datasets. Actually this diabetes problem is very much like to breast cancer classification problem shown in calss, which is a calssic problem suitable for solving with linear classification.
#
# Neural Network also performs well. But this dataset is relatively too small and thus not very suitable for solving with DNN. Neural Network will perform better if there is more data. And there are a lot more hyperparameters that we can tune on to make both the classifiers better, for example adjusting learning rate, increasing training steps and create polynomial features.
